-- %%
-- 5. Historial de la tabla: Delta guarda cada versión
DESCRIBE HISTORY workspace.practica.viajes_por_dia;

-- 6. Metadatos: ubicación, formato, propiedades
DESCRIBE EXTENDED workspace.practica.viajes_por_dia;
