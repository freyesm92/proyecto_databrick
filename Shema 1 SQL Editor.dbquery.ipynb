-- %%
-- 1. Crea tu propio schema dentro de Unity Catalog
CREATE SCHEMA IF NOT EXISTS workspace.practica
COMMENT 'Schema personal para ejercicios de El Pipeline';

-- 2. Explora el catálogo de ejemplos
SELECT * FROM samples.nyctaxi.trips LIMIT 5;
